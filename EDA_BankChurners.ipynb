# %%
#import the libaries to work with
import pandas as pd
import numpy as np

#import visualization libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Read BankChurners file

data = pd.read_csv(r'BankChurners.csv')

# %%
#Let's see what we have in the data
data.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
# 6  810347208  Existing Customer            51      M                4
# 7  818906208  Existing Customer            32      M                0
# 8  710930508  Existing Customer            37      M                3
# 9  719661558  Existing Customer            48      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# ...

# %%
#use the tail() method to view the last few rows of the data in lagos_houses
data.tail(10)
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10117  712503408  Existing Customer            57      M                2
# 10118  713755458  Attrited Customer            50      M                1
# 10119  716893683  Attrited Customer            55      F                3
# 10120  710841183  Existing Customer            54      M                1
# 10121  713899383  Existing Customer            56      F                1
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10117        Graduate        Married    $80K - $120K          Blue
# ...

# %%
#Number of rows and columns
data.shape
# Out:
# (10127, 23)

# %%
#checking if there is a missing data
data.isna().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
'''There are no missing data'''
# Out:
# 'There are no missing data'

# %%
#Use info() method to view datatypes and null counts
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
#if the data set has a large number of columns, you can view the column names by accessing the columns attribute
data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
#how many contacts are there by ClientNum
#your code here
data.CLIENTNUM.nunique()
# Out:
# 10127

# %%
data.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
data.describe().astype(int)
# Out:
#        CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count      10127         10127            10127           10127
# mean   739177606            46                2              35
# std     36903783             8                1               7
# min    708082083            26                0              13
# 25%    713036770            41                1              31
# 50%    717926358            46                2              36
# 75%    773143533            52                3              40
# max    828343083            73                5              56
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count                     10127                   10127
# mean                          3                       2
# std                           1                       1
# min                           1                       0
# 25%                           3                       2
# ...

# %%
#Relationship and insights

# %%
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
#checking for missing values or empty columns
missing_rows = (data.isnull().sum())
data.loc[missing_rows]
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 0  768805383  Existing Customer            45      M                3
# 0  768805383  Existing Customer            45      M                3
# 0  768805383  Existing Customer            45      M                3
# 0  768805383  Existing Customer            45      M                3
# 0  768805383  Existing Customer            45      M                3
# 0  768805383  Existing Customer            45      M                3
# 0  768805383  Existing Customer            45      M                3
# 0  768805383  Existing Customer            45      M                3
# 0  768805383  Existing Customer            45      M                3
# 0  768805383  Existing Customer            45      M                3
# 0  768805383  Existing Customer            45      M                3
# ...

# %%
#Total transaction Amount by the bank
#your code here
data.Total_Trans_Amt.sum()
# Out:
# 44600182

# %%
#Total Card Category by the bank
#your code here
data.Card_Category.value_counts()
# Out:
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: Card_Category, dtype: int64

# %%
#Total number of card Category
data.Card_Category.value_counts().nunique()
# Out:
# 4

# %%
#Total card issued to Clients
data.Card_Category.value_counts().sum()
# Out:
# 10127

# %%
#Card Issued
'''it means all the clients that registered with the bank got their cards issued to them'''
# Out:
# 'it means all the clients that registered with the bank got their cards issued to them'

# %%
#Total transactions done by the bank
#your code here
data.Total_Trans_Ct.value_counts().nunique()
# Out:
# 95

# %%
#Total uniques transactions done
len(data.groupby('Total_Trans_Ct').Total_Trans_Amt.nunique())
#data[data.Total_Trans_Amt].Total_Trans_Ct.nunique()
# Out:
# 126

# %%
#Total revolving balance
data.Total_Revolving_Bal.sum()
# Out:
# 11775818

# %%
#The average customer age
round(data.Customer_Age.mean(),)
# Out:
# 46

# %%
percent_gender = data.groupby('Total_Trans_Amt').Gender.sum().reset_index(name = 'Gender')
percent_gender
# Out:
#       Total_Trans_Amt Gender
# 0                 510      F
# 1                 530      M
# 2                 563      M
# 3                 569      M
# 4                 594      F
# ...               ...    ...
# 5028            17628      M
# 5029            17634      M
# 5030            17744      M
# 5031            17995      M
# 5032            18484      M
#
# [5033 rows x 2 columns]

# %%
#Total number of males and females
data.Gender.value_counts()
# Out:
# F    5358
# M    4769
# Name: Gender, dtype: int64

# %%
#function to display values on each plot
def show_values(axs, orient = 'v', space = 0.01):
    def _single(ax):
        if orient == 'v':
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height() + (p.get_height() * 0.01)
                value = '{:.1f}'.format(p.get_height())
                ax.text(_x, _y, value, ha = 'center') 
        elif orient == 'h':
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - (p.get_height() * 0.5)
                value = '{:.1f}'.format(p.get_width())
                ax.text(_x, _y, value, ha = 'left')

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)

# %%
#Total transaction Amount
Total_Amt = data.Total_Trans_Amt.sum().astype('int')
Total_Amt
# Out:
# 44600182

# %%
#Total transaction by Gender(male and female)
pivot_4 = data.groupby('Gender').Total_Trans_Amt.sum().astype('int')
pivot_4
# Out:
# Gender
# F    23169697
# M    21430485
# Name: Total_Trans_Amt, dtype: int32

# %%
#plot the bar chart
plt.bar(x = pivot_4.index, height = pivot_4)

plt.title('Total Males and Females by Total_trans_Amt')
plt.ylabel('data.astype(int)')
# Out:
# Text(0, 0.5, 'data.astype(int)')

# %%
#plot for Gender column by count
a = sns.countplot(x = data.Gender, data = data, palette = ['#432371', '#ff00b4'])
plt.title('Genders by Total_trans_Count', weight='bold').set_fontsize('16')
show_values(a)

# %%
#Percentage of Male and female by Total transaction Amount
(data.groupby('Gender').Total_Trans_Amt.sum() / 
 data.Total_Trans_Amt.sum() * 100).astype('int').apply(lambda x : str(x) + '%').reset_index(name = 'Perc_Gender')
# Out:
#   Gender Perc_Gender
# 0      F         51%
# 1      M         48%

# %%
pivot_3 = (data.groupby('Gender').Total_Trans_Amt.sum() / data.Total_Trans_Amt.sum() * 100).astype('int')
pivot_3
# Out:
# Gender
# F    51
# M    48
# Name: Total_Trans_Amt, dtype: int32

# %%
colors = ['#1f77b4', '#ff7f0e','#2ca02c', '#d62728', '#8c564b']
explode = (0.1, 0, 0, 0, 0)
plt.pie(pivot_3, labels = pivot_3.index  , colors = colors, 
        autopct = '%1.1f%%', shadow = True, startangle = 140)
 
plt.title('Percent of Male and female by Total_trans_Amount')

plt.show()

# %%
#Average Customer age by Card category
data.groupby('Card_Category').Customer_Age.mean().astype(int).reset_index(name = 'Avg_age')
# Out:
#   Card_Category  Avg_age
# 0          Blue       46
# 1          Gold       45
# 2      Platinum       47
# 3        Silver       45

# %%
pivot_1 = data.groupby('Card_Category').Customer_Age.mean().astype(int)
pivot_1
# Out:
# Card_Category
# Blue        46
# Gold        45
# Platinum    47
# Silver      45
# Name: Customer_Age, dtype: int32

# %%
colors = ['#1f77b4', '#ff7f0e','#2ca02c', '#d62728', '#8c564b']
explode = (0.1, 0, 0, 0, 0)
plt.pie(pivot_1, labels = pivot_1.index  , colors = colors, 
        autopct = '%1.1f%%', shadow = True, startangle = 140)
 
plt.title('Card Category by Average Age')

plt.show()

# %%
data.groupby('Marital_Status').Total_Relationship_Count.value_counts().astype(int).reset_index(name = 'Total_Relations')
# Out:
#    Marital_Status  Total_Relationship_Count  Total_Relations
# 0        Divorced                         3              171
# 1        Divorced                         5              160
# 2        Divorced                         4              137
# 3        Divorced                         6              133
# 4        Divorced                         2               84
# 5        Divorced                         1               63
# 6         Married                         3             1110
# 7         Married                         6              883
# 8         Married                         4              877
# 9         Married                         5              873
# 10        Married                         2              558
# 11        Married                         1              386
# 12         Single                         3              889
# 13         Single                         4              761
# ...

# %%
#Marital Status by Total Relationship Count
data.groupby('Marital_Status').Total_Relationship_Count.count().astype(int).reset_index(name = 'Total_Relations')
# Out:
#   Marital_Status  Total_Relations
# 0       Divorced              748
# 1        Married             4687
# 2         Single             3943
# 3        Unknown              749

# %%
#Marital Status by Total Relationship Count
pivot_2 = data.groupby('Marital_Status').Total_Relationship_Count.count().astype(int)
pivot_2
# Out:
# Marital_Status
# Divorced     748
# Married     4687
# Single      3943
# Unknown      749
# Name: Total_Relationship_Count, dtype: int32

# %%
#Marital Status by Total Relationship Count
#plot the bar chart

def add_value_label(x_list,y_list):
    for i in range(1, len(x_list)+1):
        plt.text(i,y_list[i-1],y_list[i-1], ha = 'center')
        

plt.title('Marital Status by Total Relationship Count')

plt.bar(x = pivot_2.index, height = pivot_2)
plt.xlabel('Marital Status')
plt.ylabel('Relationship Count')
plt.show()

# %%
#Customer age by Credit limit
pivot_5 = data.groupby('Customer_Age').Credit_Limit.sum().astype(int).reset_index(name = 'Total_Credit_Limit')
pivot_5
# Out:
#     Customer_Age  Total_Credit_Limit
# 0             26              358172
# 1             27              177055
# 2             28              258393
# 3             29              417606
# 4             30              452625
# 5             31              771425
# 6             32              866115
# 7             33              946886
# 8             34             1075176
# 9             35             1312366
# 10            36             1585343
# 11            37             1799262
# 12            38             2642387
# 13            39             2891520
# 14            40             3375572
# 15            41             3742596
# 16            42             3676776
# 17            43             4352893
# 18            44             4814158
# 19            45             4270637
# 20            46             4558087
# 21            47             4185399
# 22            48             4268431
# 23            49             4620276
# ...

# %%
#Customer Age by Credit Limit
plt.hist(data.Customer_Age)

plt.title('Customer Age by Credit Limit')

plt.ylabel('Credit_Limit')
plt.xlabel('Customer_Age')
# Out:
# Text(0.5, 0, 'Customer_Age')

# %%
#Education Level by Total transaction Amount
pivot_6 = data.groupby('Education_Level').Total_Trans_Amt.sum().astype(int).reset_index(name = 'Total_Trans_Amt')
pivot_6
# Out:
#   Education_Level  Total_Trans_Amt
# 0         College          4311132
# 1       Doctorate          1891050
# 2        Graduate         13821041
# 3     High School          8864729
# 4   Post-Graduate          2329954
# 5      Uneducated          6668215
# 6         Unknown          6714061

# %%
#view distribution of Total tran Amount by Education level
#Box_plot#import visualization libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
fig, ax = plt.subplots(1,figsize=(12,8))
sns.boxplot(x = data.Education_Level, y = data.Total_Trans_Amt, data = data)

plt.show()

# %%
#Marital status Level by Total revolving Balance
pivot_7 = data.groupby('Marital_Status').Total_Revolving_Bal.sum().astype('int')
pivot_7
# Out:
# Marital_Status
# Divorced     864674
# Married     5611106
# Single      4432884
# Unknown      867154
# Name: Total_Revolving_Bal, dtype: int32

# %%
#Marital status Level by Total revolving Balance plot on a horizontal bar chart
plt.title('Marital Status by Total Revolving Balance')

plt.barh(y=pivot_7.index, width=pivot_7)
plt.xlabel('Marital Status')
plt.ylabel('Revolving Balance')
plt.show()

# %%
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
pivot_8 = data.groupby('Income_Category').Customer_Age.mean().astype(int)
pivot_8
# Out:
# Income_Category
# $120K +           47
# $40K - $60K       46
# $60K - $80K       45
# $80K - $120K      46
# Less than $40K    46
# Unknown           46
# Name: Customer_Age, dtype: int32

# %%
plt.figure(figsize = [20, 10])
sns.heatmap(data.corr(),cmap='magma', annot=True)
plt.title('Correlation between Income Category and Avg_Cust.Age', weight='bold').set_fontsize('16')

# %%
#Income category by the number of male and females
Inc_Gen = data.groupby('Income_Category').Gender.value_counts()
Inc_Gen
# Out:
# Income_Category  Gender
# $120K +          M          727
# $40K - $60K      F         1014
#                  M          776
# $60K - $80K      M         1402
# $80K - $120K     M         1535
# Less than $40K   F         3284
#                  M          277
# Unknown          F         1060
#                  M           52
# Name: Gender, dtype: int64

# %%
'''This shows that 727 males are earning $120k plus, 776 males and 1014 females are earning between $40k and $60k. 
A larger percent of males are earning more than females which for Gender equality in the work force. Also, 
the existing customers of the bank are mostly females performing higher transactions than the males'''
# Out:
# 'This shows that 727 males are earning $120k plus, 776 males and 1014 females are earning between $40k and $60k. \nA larger percent of males are earning more than females which for Gender equality in the work force. Also, \nthe existing customers of the bank are mostly females performing higher transactions than the males'

# %%
data.head()
#data.groupby('Income_Category').Gender.value_counts()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...
